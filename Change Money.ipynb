# %%
USD = float(input("Input your money which need change to VND: "))
rate = float(input("Input rate today: "))
VND = USD * rate
print(VND)
# Out:
# Input your money which need change to VND: 500
# Input rate today: 23489
# 11744500.0
